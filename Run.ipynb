# %%
# %run main.py --start 1 --end 8
# Out:
# >>> Running pipeline from step 1 to 8
#
# === Step 1: LOAD ===
# Loading dataset...
#                            time     open     high      low    close  volume  \
# Date
# 2014-12-31 18:00:00  1420048800  1.20997  1.21089  1.20966  1.20999    3237
# 2015-01-02 08:00:00  1420185600  1.20481  1.20569  1.20479  1.20538    1254
# 2015-01-02 09:00:00  1420189200  1.20537  1.20574  1.20341  1.20553    3394
# 2015-01-02 10:00:00  1420192800  1.20556  1.20689  1.20442  1.20469    4590
# 2015-01-02 11:00:00  1420196400  1.20468  1.20599  1.20380  1.20573    4335
#
#                      spread  real_volume  Signal                Date
# Date
# 2014-12-31 18:00:00      17            0       0 2014-12-31 18:00:00
# 2015-01-02 08:00:00      17            0       0 2015-01-02 08:00:00
# 2015-01-02 09:00:00      17            0       0 2015-01-02 09:00:00
# 2015-01-02 10:00:00      17            0       0 2015-01-02 10:00:00
# ...

# %%
pip install xgboost
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 21.2.3; however, version 25.3 is available.
# You should consider upgrading via the 'c:\Users\h\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %%
pip install TA-Lib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 21.2.3; however, version 25.3 is available.
# You should consider upgrading via the 'c:\Users\h\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %%
# %run main_updated.py --start 1 --end 7
# Out:
# Running pipeline from step 1 to 7
# Running step: load
# Loading dataset...
#                            time     open     high      low    close  volume  \
# Date
# 2014-12-31 18:00:00  1420048800  1.20997  1.21089  1.20966  1.20999    3237
# 2015-01-02 08:00:00  1420185600  1.20481  1.20569  1.20479  1.20538    1254
# 2015-01-02 09:00:00  1420189200  1.20537  1.20574  1.20341  1.20553    3394
# 2015-01-02 10:00:00  1420192800  1.20556  1.20689  1.20442  1.20469    4590
# 2015-01-02 11:00:00  1420196400  1.20468  1.20599  1.20380  1.20573    4335
#
#                      spread  real_volume  Signal                Date
# Date
# 2014-12-31 18:00:00      17            0       0 2014-12-31 18:00:00
# 2015-01-02 08:00:00      17            0       0 2015-01-02 08:00:00
# 2015-01-02 09:00:00      17            0       0 2015-01-02 09:00:00
# 2015-01-02 10:00:00      17            0       0 2015-01-02 10:00:00
# 2015-01-02 11:00:00      17            0       0 2015-01-02 11:00:00
# ...

# %%
pip install keras
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The script markdown-it.exe is installed in 'c:\Users\h\AppData\Local\Programs\Python\Python310\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# WARNING: You are using pip version 21.2.3; however, version 25.3 is available.
# You should consider upgrading via the 'c:\Users\h\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %%
pip install tensorflow
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The script wheel.exe is installed in 'c:\Users\h\AppData\Local\Programs\Python\Python310\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script markdown_py.exe is installed in 'c:\Users\h\AppData\Local\Programs\Python\Python310\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script normalizer.exe is installed in 'c:\Users\h\AppData\Local\Programs\Python\Python310\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script tensorboard.exe is installed in 'c:\Users\h\AppData\Local\Programs\Python\Python310\Scripts' which is not on PATH.
# ...

# %%
# %run main_updated.py --start 1 --end 7
# Out:
# Running pipeline from step 1 to 7
# Running step: load
# Loading dataset...
#                            time     open     high      low    close  volume  \
# Date
# 2014-12-31 18:00:00  1420048800  1.20997  1.21089  1.20966  1.20999    3237
# 2015-01-02 08:00:00  1420185600  1.20481  1.20569  1.20479  1.20538    1254
# 2015-01-02 09:00:00  1420189200  1.20537  1.20574  1.20341  1.20553    3394
# 2015-01-02 10:00:00  1420192800  1.20556  1.20689  1.20442  1.20469    4590
# 2015-01-02 11:00:00  1420196400  1.20468  1.20599  1.20380  1.20573    4335
#
#                      spread  real_volume  Signal                Date
# Date
# 2014-12-31 18:00:00      17            0       0 2014-12-31 18:00:00
# 2015-01-02 08:00:00      17            0       0 2015-01-02 08:00:00
# 2015-01-02 09:00:00      17            0       0 2015-01-02 09:00:00
# 2015-01-02 10:00:00      17            0       0 2015-01-02 10:00:00
# 2015-01-02 11:00:00      17            0       0 2015-01-02 11:00:00
# ...
